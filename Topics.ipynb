# %%
# !pip install bertopic
# !pip install sentence-transformers
# Out:
# Collecting bertopic
#   Downloading bertopic-0.17.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: hdbscan>=0.8.29 in /usr/local/lib/python3.11/dist-packages (from bertopic) (0.8.40)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (2.0.2)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.11/dist-packages (from bertopic) (2.2.2)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (5.24.1)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (1.6.1)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from bertopic) (3.4.1)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.11/dist-packages (from bertopic) (4.67.1)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (0.5.7)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.11/dist-packages (from hdbscan>=0.8.29->bertopic) (1.14.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from hdbscan>=0.8.29->bertopic) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=4.7.0->bertopic) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly>=4.7.0->bertopic) (24.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0->bertopic) (3.6.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.51.3)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.6.0+cu124)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.30.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (11.1.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.11/dist-packages (from umap-learn>=0.5.0->bertopic) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.11/dist-packages (from umap-learn>=0.5.0->bertopic) (0.5.13)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2025.3.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (4.13.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic) (1.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.5.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2025.1.31)
# Downloading bertopic-0.17.0-py3-none-any.whl (150 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.6/150.6 kB 8.3 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 106.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 89.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.6 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 43.0 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.8 MB/s eta 0:00:00
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /packages/db/f7/97a9ea26ed4bbbfc2d470994b8b4f338ef663be97b8f677519ac195e113d/nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.6 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 104.9 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, bertopic
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed bertopic-0.17.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (3.4.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.51.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (2.6.0+cu124)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.14.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (0.30.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.1.31)

# %%
from bertopic import BERTopic

print("importing - past bert")

import pandas as pd
import numpy as np
import re
from hdbscan import HDBSCAN
from pickle import dump, load
import gc
import os
from bertopic.representation import KeyBERTInspired, OpenAI, MaximalMarginalRelevance
# import api_key
import openai
import matplotlib.pyplot as plt
import seaborn as sns
from sentence_transformers import SentenceTransformer

def visualize_topic_scores(topic_scores, topic_names, product_name):
    labels = [topic_names[k] for k in topic_scores.keys()]
    scores = [topic_scores[k] for k in topic_scores.keys()]
    plt.figure(figsize=(12, 7))
    sns.barplot(x=scores, y=labels, palette="coolwarm", orient='h')
    plt.axvline(x=0, color='black', linestyle='--', linewidth=1)
    plt.title(f"Sentiment-Weighted Topic Scores\nProduct: {product_name}")
    plt.xlabel("Normalized Sentiment Score")
    plt.ylabel("Topics")
    plt.tight_layout()
    safe_name = re.sub(r'[^A-Za-z0-9]', '_', product_name)[:30]
    plt.savefig(f"plots/{safe_name}_topic_scores.png")
    plt.close()

def pretty_print(dict_in, names):
    for key in sorted(dict_in.keys()):
        print(f"{key}, {names[key]}: {dict_in[key]}")

os.environ["TOKENIZERS_PARALLELISM"] = "false"
os.environ["OMP_NUM_THREADS"] = "1"

print("all libraries imported")

data = pd.read_csv("input_data.csv")
df = pd.DataFrame(data)

print("data in")

product_dict = {
    re.sub(r'[^A-Za-z0-9 ]', '', product)[:30]: group[['product_name','Rate', 'Summary', 'Sentiment']].reset_index(drop=True)
    for product, group in df.groupby('product_name')
}

print(f"{len(product_dict.keys())}")

filtered_products = {}

for name, curr_product in product_dict.items():
    curr_product = curr_product.dropna(subset=['Summary'])
    curr_product = curr_product[curr_product['Summary'].apply(lambda x: len(str(x).split()) > 10)]

    reviews = curr_product['Summary'].tolist()
    sentiments = curr_product['Sentiment'].tolist()

    if (len(reviews) >= 150) and (len([x for x in sentiments if x == "negative"]) > 100):
        filtered_products[name] = curr_product.copy()

print("filtered data len: " + str(len(filtered_products.keys())))

f = open("product_topics.pkl", "wb")
dump(len(filtered_products.keys()), f)
product_topics = {}
i = 0

key_model = KeyBERTInspired()

embedding_model = SentenceTransformer("all-MiniLM-L6-v2", device='cuda')

mmr_model = MaximalMarginalRelevance(diversity=0.3)

client = openai.OpenAI(api_key=key_)
ai_model = OpenAI(client, model="gpt-4o-mini", chat=True)

rep_models = [key_model, mmr_model]

custom_hdbscan = HDBSCAN(min_cluster_size=5, min_samples=2, prediction_data=True)

for name, product in filtered_products.items():
    print("\n  --------------------- \n")
    print(name + " being processed")
    summaries = product['Summary'].tolist()
    sentiments = product['Sentiment'].tolist()
    topic_model = BERTopic(language="english", hdbscan_model=custom_hdbscan, representation_model=rep_models, embedding_model=embedding_model)

    topics, _ = topic_model.fit_transform(summaries)
    topic_model.reduce_topics(summaries, nr_topics="auto")
    topics, _ = topic_model.transform(summaries)

    num_of_pos = sentiments.count("positive")
    num_of_neg = sentiments.count("negative")
    ratings_normalized = [int(x) - 3 for x in product['Rate'].tolist()]

    product['Topic'] = topics
    product_topics[name] = {
        "data": product,
        "model": topic_model
    }

    topic_scores = {}
    for topic in topics:
        topic_scores[topic] = 0

    for summary, topic, sentiment, rating in zip(summaries, topics, sentiments, ratings_normalized):
        #print(f"Summary: {summary[:60]}... → Topic: {topic} → Sentiment: {sentiment}")
        num = num_of_neg if sentiment == "negative" else num_of_pos
        topic_scores[topic] += rating / num

    topic_info = topic_model.get_topic_info()
    topic_names = topic_info.set_index("Topic")["Name"].to_dict()

    pretty_print(topic_scores, topic_names)

    os.makedirs("plots", exist_ok=True)
    visualize_topic_scores(topic_scores, topic_names, name)

    # Save intermediate results
    data = {"product data": product, "topic info": topic_info, "topic names": topic_names, "topic scores": topic_scores}
    dump(data, f)

    # Clear memory
    del topic_model
    gc.collect()

f.close()
# Out:
# importing - past bert
# all libraries imported
# data in
# 861
# filtered data len: 5
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
#   ---------------------
#
# Butterfly Rapid 750 W Juicer M being processed
# -1, -1_motor_grinder_quality_grinding: 0.02624548169102627
# 0, 0_jars_jar_juicer_mixer: 0.005225522552253833
# 1, 1_delivery_flipkart_delivered_product: -0.097752632406099
# 2, 2_blade_blades_sharpen_sharp: -0.12871287128712872
#
#   ---------------------
#
# Crompton 75 L Desert Air Coole being processed
# -1, -1_cooling_cooler_ventilation_air: 0.17556935817805397
# 0, 0_cooling_cooler_coolers_ventilation: 0.7229813664596259
# 1, 1_flipkart_flipcart_products_product: -0.10641821946169772
# 2, 2_pump_motor_roomwater_descriptionhoweverwater: -0.20372670807453414
# 3, 3_water_pump_drain_dispenser: -0.0712215320910973
# 4, 4_plastic_quality_cooling_design: 0.01946169772256729
# 5, 5_defective_flaps_problem_cleanliness: -0.03229813664596273
# 6, 6_scratches_scratch_cooling_product: -0.0016563146997929622
# 7, 7_deliveryproduct_delivery_delivered_packing: -0.02070393374741201
#
#   ---------------------
#
# Mi 5A 80 cm 32 inch HD Ready L being processed
# -1, -1_tv_quality_android_hd: 0.15465258819724834
# 0, 0_sony_tv_quality_hd: 0.7344531432138283
# 1, 1_flipkart_flipcart_installation_install: 0.10366325985756072
# 2, 2_mirroring_mirror_screen_chromecast: -0.02467116395550842
# 3, 3_brightness_backlight_tv_led: 0.04871060171919772
# 4, 4_wifi_24ghz_connectivity_5ghz: -0.05069226661853514
# 5, 5_tv_wallmount_hdmi_wall: -0.007385180004361915
# 6, 6_tv_screen_repair_display: -0.1614173228346456
# 7, 7_tv_installation_installedcalled_installedi: -0.040674894148260116
# 8, 8_bluetooth_bluetoothapart_tv_connecting: -0.032684309876738184
# 9, 9_netflix_tv_prime_firmware: -0.019801607893569176
# 10, 10_wireless_wifi_connectivity_mobile: -0.010017372470275027
# 11, 11_installation_mounting_wall_mount: -0.018846498055937848
# 12, 12_tv_hdmi_tvunder_tvafter: -0.018846498055937848
# 13, 13_1080p_ram_720p_tv: -0.00596379607276884
# 14, 14_lagging_lags_tv_lagsrunning: -0.017774819694816084
# 15, 15_qualitybut_resolution_quality_sound: -0.007874015748031496
#
#   ---------------------
#
# POCO C31 Royal Blue 64 GB4 GB  being processed
# -1, -1_quality_performance_battery_camera: 0.22209962168978564
# 0, 0_smartphone_phone_budget_carrier: 0.32361286254728877
# 1, 1_camera_smartphone_quality_phone: 0.1639344262295082
# 2, 2_mobile_mobiles_screen_app: -0.12815258511979824
# 3, 3_products_quality_product_performance: 0.12831021437578816
# 4, 4_poco_mobile_c31_phone: -0.03877679697351829
# 5, 5_mobile_phone_lagging_bluetooth: -0.17307692307692307
# 6, 6_problemphone_phone_calls_quality: -0.14423076923076925
# 7, 7_mobile_speaker_sound_flickering: -0.05091424968474149
# 8, 8_flipkart_phone_mobiletotally_samsung: -0.09757250945775536
# 9, 9_camera_camera4_battery_goodcamera: 0.01355611601513241
# 10, 10_camera_megapixel_quality_mobile: -0.10576923076923078
# 11, 11_mobile_phone_hanging_hang: -0.11254728877679698
# 12, 12_camera_quality_lagging_mobile: -0.07692307692307693
# 13, 13_backup_battery_camera_camrabattery: -0.02490542244640605
# 14, 14_camera_quality_phoneso_phone: 0.05737704918032787
# 15, 15_calls_phone_calling_call: -0.07692307692307693
# 16, 16_mobile_phone_screen_camera: -0.031683480453972256
# 17, 17_charging_charge_slow_mobile: -0.022068095838587643
#
#   ---------------------
#
# Pigeon Favourite Electric Kett being processed
# -1, -1_quality_products_product_service: -0.30144500936580143
# 0, 0_kettle_boiling_boil_boiled: 0.163031843724913
# 1, 1_service_product_customer_using: -0.18122825796093117
# 2, 2_indicator_switch_light_wire: -0.008027829810008024
# 3, 3_flipkart_flipkarts_flipcartafter_products: 0.02120685041477121
# 4, 4_quality_steel_materials_material: 0.0009365801445009349
# 5, 5_automatic_appliance_automatically_autocut: -0.048568370350548576
# 6, 6_review_reviewing_reviewafter_months: 0.06442333422531443
# 7, 7_delivery_delivered_quality_packing: 0.03063955044153064
# 8, 8_burntcap_cap_quality_plastic: -0.04321648381054322
# 9, 9_months_month_failure_worked: -0.0891089108910891
# 10, 10_boiling_boil_wire_boiled: 0.02027027027027027

# %%
from bertopic import BERTopic

print("importing - past bert")

import pandas as pd
import numpy as np
import re
from hdbscan import HDBSCAN
from pickle import dump, load
import gc
import os
from bertopic.representation import KeyBERTInspired, OpenAI, MaximalMarginalRelevance
# import api_key
import openai
from sentence_transformers import SentenceTransformer

def pretty_print(dict_in, names):
    for key in sorted(dict_in.keys()):
        print(f"{key}, {names[key]}: {dict_in[key]}")

os.environ["TOKENIZERS_PARALLELISM"] = "false"
os.environ["OMP_NUM_THREADS"] = "1"

print("all libraries imported")

data = pd.read_csv("input_data.csv")
df = pd.DataFrame(data)

print("data in")

product_dict = {
    re.sub(r'[^A-Za-z0-9 ]', '', product)[:30]: group[['product_name','Rate', 'Summary', 'Sentiment']].reset_index(drop=True)
    for product, group in df.groupby('product_name')
}

embedding_model = SentenceTransformer("all-MiniLM-L6-v2", device='cuda')

print(f"{len(product_dict.keys())}")

filtered_products = {}

for name, curr_product in product_dict.items():
    curr_product = curr_product.dropna(subset=['Summary'])
    curr_product = curr_product[curr_product['Summary'].apply(lambda x: len(str(x).split()) > 10)]

    reviews = curr_product['Summary'].tolist()
    sentiments = curr_product['Sentiment'].tolist()

    if (len(reviews) >= 20) and (len([x for x in sentiments if x == "negative"]) > 10):
        filtered_products[name] = curr_product.copy()

print("filtered data len: " + str(len(filtered_products.keys())))

f = open("product_topics.pkl", "wb")
dump(len(filtered_products.keys()), f)
product_topics = {}
i = 0

key_model = KeyBERTInspired()

mmr_model = MaximalMarginalRelevance(diversity=0.3)

client = openai.OpenAI(api_key=key_)
ai_model = OpenAI(client, model="gpt-4o-mini", chat=True)

rep_models = [key_model, mmr_model]

custom_hdbscan = HDBSCAN(min_cluster_size=5, min_samples=2, prediction_data=True)

for name, product in filtered_products.items():
    print("\n  --------------------- \n")
    print(name + " being processed")
    summaries = product['Summary'].tolist()
    sentiments = product['Sentiment'].tolist()
    topic_model = BERTopic(language="english", hdbscan_model=custom_hdbscan, representation_model=rep_models, embedding_model=embedding_model)

    topics, _ = topic_model.fit_transform(summaries)
    topic_model.reduce_topics(summaries, nr_topics="auto")
    topics, _ = topic_model.transform(summaries)

    num_of_pos = sentiments.count("positive")
    num_of_neg = sentiments.count("negative")
    ratings_normalized = [int(x) - 3 for x in product['Rate'].tolist()]

    product['Topic'] = topics
    product_topics[name] = {
        "data": product,
        "model": topic_model
    }

    topic_scores = {}
    for topic in topics:
        topic_scores[topic] = 0

    for summary, topic, sentiment, rating in zip(summaries, topics, sentiments, ratings_normalized):
        #print(f"Summary: {summary[:60]}... → Topic: {topic} → Sentiment: {sentiment}")
        num = num_of_neg if sentiment == "negative" else num_of_pos
        topic_scores[topic] += rating / num

    topic_info = topic_model.get_topic_info()
    topic_names = topic_info.set_index("Topic")["Name"].to_dict()

    pretty_print(topic_scores, topic_names)

    # Save intermediate results
    data = {"product data": product, "topic info": topic_info, "topic names": topic_names, "topic scores": topic_scores}
    dump(data, f)

    # Clear memory
    del topic_model
    gc.collect()

f.close()
# Out:
# importing - past bert
# all libraries imported
# data in
# 861
# filtered data len: 176
#
#   ---------------------
#
# AGARO Regal Handheld Vacuum Cl being processed
# -1, -1_vacuum_cleaner_cleaners_cleaning: 0.17343304843304838
# 0, 0_vacuum_cleaner_cleaning_suction: 0.014601139601139373
# 1, 1_quality_service_review_product: -0.13141025641025655
# 2, 2_cord_length_useful_vacuum: 0.17307692307692304
# 3, 3_car_useful_portable_handy: 0.02314814814814815
# 4, 4_wattsheating_heating_800w_2000w: -0.08048433048433049
# 5, 5_delivery_packing_packed_delivered: 0.03703703703703704
# 6, 6_filters_filter_filterhighly_cleaner: -0.00498575498575498
# 7, 7_quality_satisfied_productnever_product: 0.02849002849002849
#
#   ---------------------
#
# APPLE 2020 Macbook Air M1  8 G being processed
# -1, -1_laptop_performance_macbook_quality: 0.21932173136992408
# 0, 0_macbook_laptop_m1_mac: 0.31381079875055773
# 1, 1_laptop_laptops_performance_quality: 0.17257920571173585
# 2, 2_processor_performance_machine_xampp: 0.13554216867469884
# 3, 3_flipkart_delivery_flipkar_packaging: 0.08645693886657745
# 4, 4_apple_mac_apps_laptop: 0.26561802766622045
# 5, 5_backup_battery_macbookbattery_intels: 0.01929941990182954
# 6, 6_macbook_mac_performance_battery: 0.060240963855421686
# 7, 7_macbooks_macbook_mac_macbookswitched: 0.05421686746987951
# 8, 8_macbook_mac_flipkart_apple: 0.05421686746987951
# 9, 9_laptop_laptop2_performance_laptopsgood: 0.03614457831325302
# 10, 10_laptop_batteryit_android_battery: 0.0391566265060241
# 11, 11_performance_multimedia_emulator_apple: 0.048192771084337345
# 12, 12_m1_chip_vm_ultimate: 0.03313253012048193
# 13, 13_laptop_laptops_windows_os: 0.10720660419455602
# 14, 14_macbook_laptop_mac_apple: 0.04216867469879518
# 15, 15_battery_quality_screen_performance: 0.04216867469879518
# 16, 16_ssd_512gb_256gb_8gb: 0.027108433734939756
# 17, 17_webcam_camera_apple_macbook: -0.08701472556894242
# 18, 18_macbook_laptop_laptops_apple: 0.03313253012048193
# 19, 19_charging_charger_apple_faulty: -0.14513609995537705
# 20, 20_laptop_lag_quality_backlighting: 0.03614457831325301
# 21, 21_worth_price_sleek_purchase: 0.03614457831325301
# 22, 22_performance_displaymonster_sound_display: 0.030120481927710843
# 23, 23_ios_android_app_mobile: 0.030120481927710843
# 24, 24_mac_apple_glossy2_pros: 0.027108433734939756
# 25, 25_macbook_flipkart_mac_packaging: 0.030120481927710843
# 26, 26_macbook_mac_apple_laptopi: 0.030120481927710843
#
#   ---------------------
#
# APPLE iPad 9th Gen 64 GB ROM 1 being processed
# -1, -1_ipad_tablet_apple_device: 0.2795031055900624
# 0, 0_apple_performance_products_smooth: 0.3149585921325054
# 1, 1_camera_quality_performance_cam: 0.17701863354037267
# 2, 2_ipad_ios_performance_device: 0.08255693581780536
# 3, 3_ipad_camera_ios_apple: 0.10248447204968943
# 4, 4_flipkart_delivery_flipkartbecause_shipping: 0.016045548654244284
# 5, 5_ipad_tablet_ipads_ipad5: 0.09316770186335402
# 6, 6_ipad_ipaddelivery_apple_bestnote: 0.17028985507246383
# 7, 7_value_price_moneyeveryone_buy: -0.011904761904761916
# 8, 8_ipad_ios_apple_screen: -0.02122153209109732
# 9, 9_price_worth_30k_budget: 0.1871118012422361
# 10, 10_tablet_tablets_tab_budget: 0.06521739130434781
# 11, 11_students_student_tablet_classes: 0.05900621118012421
# 12, 12_lag_laggy_lags_gaming: 0.13612836438923395
# 13, 13_ipad_flipkart_flipkartperformance_flipcart: 0.05279503105590061
# 14, 14_battery_lcd_screen_quality: 0.04037267080745341
# 15, 15_tab_tablet_tabs_performance: 0.12060041407867494
# 16, 16_ipad_apple_device_screen: 0.03105590062111801
# 17, 17_gaming_performance_gaminglong_games: 0.11128364389233954
# 18, 18_ipad_tablets_ios_apple: -0.06159420289855072
# 19, 19_tab_tabs_android_pad: 0.06340579710144928
#
#   ---------------------
#
# ASUS TUF Gaming A17 with 90Whr being processed
# -1, -1_laptop_gaming_quality_144hz: 0.19047619047619047
# 0, 0_1080_4k60fps_laptop_performance: 0.199813258636788
# 1, 1_reinstall_passwords_malfunctioning_errors: -0.7282913165266107
# 2, 2_laptop_gaming_performance_gamer: 0.2857142857142857
# 3, 3_laptop_laptops_asus_keyboard: 0.25396825396825395
# 4, 4_laptop_battery_asus_60kperformance: 0.2222222222222222
# 5, 5_laptop_ryzen_processor_hp: 0.12698412698412698
# 6, 6_laptop_affordable_mouse_budget: 0.15873015873015872
# 7, 7_laptop_speakers_speaker_asus: 0.14939309056956115
# 8, 8_laggy_chrome_lag_tabs: 0.3622782446311858
#
#   ---------------------
#
# ASUS TUF Gaming F15 Core i5 10 being processed
# -1, -1_laptop_performance_laptops_performancebest: -0.22499999999999995
# 0, 0_performance_gaming_laptop_gtx: 0.6650000000000003
# 1, 1_laptop_keyboard_asus_performance: 0.032500000000000015
# 2, 2_laptop_backup_performance_battery: 0.045
# 3, 3_performancebut_performance_performanceand_batterylife: 0.27749999999999997
# 4, 4_delivery_deliver_delivered_service: -0.19
# 5, 5_laptop_performance_battery_lap: 0.12
# 6, 6_performance_specs_useslaptop_recommends: 0.12000000000000001
# 7, 7_laptop_performance_quality_processor: 0.11
# 8, 8_quality_design_economical_expensive: 0.11000000000000001
#
#   ---------------------
#
# ASUS VivoBook 15 2022 Core i3  being processed
# -1, -1_brightness_quality_dell_battery: -0.10089399744572158
# 0, 0_laptop_performance_ram_battery: 0.5989782886334608
# 1, 1_quality_product_reliable_design: 0.17794806300553426
# 2, 2_heating_performance_laptop_heat: -0.27330779054916987
# 3, 3_screen_laptop_keyboard_mouse: -0.3005534269902086
# 4, 4_quality_camera_downpointcamera_sound: -0.034482758620689655
#
#   ---------------------
#
# Adrenex by Flipkart Big Bang 6 being processed
# -1, -1_paper_layer_ollies_kickflips: 0.058823529411764705
# 0, 0_skateboard_skate_beginners_board: 0.36231884057971014
# 1, 1_wheels_wheel_tires_tyres: 0.006820119352088663
# 2, 2_flipcart_flipkart_quality_product: 0.1483375959079284
# 3, 3_skateboard_tape_grip_board: -0.21739130434782608
#
#   ---------------------
#
# Aero Seeds 40 Varieties of Flo being processed
# -1, -1_seeds_germination_germinated_seed: -0.41310160427807485
# 0, 0_seeds_germination_seed_seedling: 0.2847593582887701
# 1, 1_seeds_germinationedit_growseeds_grow: 0.23529411764705885
# 2, 2_seeds_seed_germination_flower: 0.11363636363636365
# 3, 3_seeds_seed_germinatedlast_germinated: 0.11497326203208558
# 4, 4_germination_germinate_germinationdont_germinates: -0.4866310160427808
#
#   ---------------------
#
# Aero Seeds Aero Seeds 45 Varie being processed
# -1, -1_quality_seeds_packetlet_packed: 0.3076923076923077
# 0, 0_seeds_seed_germinate_germinatedfelt: 0.46153846153846156
# 1, 1_seeds_germination_germinating_quantity: -0.38461538461538464
# 2, 2_seeds_plant_plants_planter: -0.3076923076923077
#
#   ---------------------
#
# Ang Refill kit Compatible Dye  being processed
# -1, -1_ink_printer_cartridge_printing: -0.41919191919191917
# 0, 0_ink_inkjet_printer_cartridges: -0.14646464646464646
# 1, 1_ink_printing_cartridge_prints: 0.4797979797979798
# 2, 2_device_recommended_quality_productit: 0.2575757575757576
# 3, 3_ink_quality_pictures_original: 0.050505050505050525
#
#   ---------------------
#
# Apple 20W USBC Power Charging  being processed
# -1, -1_genuine_review_product_is: 0.05405405405405406
# 0, 0_charger_charging_charge_iphone13: -0.20620620620620622
# 1, 1_chargingotherwise_charging_iphone_charger: 0.34534534534534533
# 2, 2_charger_charging_expensive_price: 0.14564564564564567
# 3, 3_adapterbox_genuine_adapter_apple: 0.06106106106106107
# 4, 4_phone_refund_products_product: -0.24224224224224222
#
#   ---------------------
#
# Aquagrand SkyLand 18 Ltr RO  U being processed
# -1, -1_repair_service_quality_fault: -0.24489795918367344
# 0, 0_quality_purification_water_purified: 0.591836734693877
# 1, 1_customer_products_product_service: -0.06122448979591833
# 2, 2_repaired_product_working_stopped: -0.24489795918367344
# 3, 3_uv_leaking_leak_led: -0.16326530612244897
#
#   ---------------------
#
# Aroma NB119 Titanium  48 Hours being processed
# -1, -1_quality_bluetooth_buy_price: 0.06122448979591835
# 0, 0_backup_quality_battery_decent: 0.29513343799058084
# 1, 1_battery_hours_hoursvery_hoursamazing: 0.039246467817896355
# 2, 2_earbudsi_headset_headphone_quality: 0.4081632653061224
# 3, 3_audio_hearing_noise_earphone: -0.03139717425431715
# 4, 4_neckband_quality_nackband_cheap: 0.12244897959183673
#
#   ---------------------
#
# Atomberg Renesa 1200 mm BLDC M being processed
# -1, -1_watts_speed_fan_quality: -0.050491803278688505
# 0, 0_fan_motor_fans_noise: -0.4298360655737705
# 1, 1_flipkart_electronics_productsuper_productstaring: -0.13344262295081968
# 2, 2_air_quality_airtotally_fan: -0.16721311475409836
# 3, 3_fanthe_fan_reviews_speed: 0.16393442622950818
# 4, 4_noisy_noise_fanspeed_fan: -0.22459016393442624
# 5, 5_cooling_efficiencies_fan_performance: 0.12295081967213116
# 6, 6_fan_noiseless_noise_fans: 0.13114754098360654
# 7, 7_remote_fan_speed_light: 0.1557377049180328
# 8, 8_fan_fanremote_fanas_noise: 0.0737704918032787
# 9, 9_luminous_led_color_white: 0.05737704918032788
# 10, 10_fanremote_bldc_fan_80w: 0.06557377049180328
# 11, 11_airflow_flow_air_goodair: 0.0737704918032787
#
#   ---------------------
#
# BAJAJ 15 L Storage Water Geyse being processed
# -1, -1_geyser_heating_days_plumber: 0.019203187250995978
# 0, 0_heating_heated_heat_bath: 0.06677290836653384
# 1, 1_geyser_geysers_gyser_gysear: 0.03131474103585657
# 2, 2_installation_installationthe_installationbut_install: -0.056254980079681306
# 3, 3_bajaj_inlet_installation_plugfor: -0.028366533864541833
# 4, 4_value_quality_worth_productthis: 0.09358565737051791
# 5, 5_pipes_pipe_inlet_installation: 0.031713147410358564
# 6, 6_installation_plumber_heating_pipes: -0.012270916334661357
# 7, 7_bajaj_flipkart_bajajnot_pricing: 0.021713147410358565
# 8, 8_installation_install_instalation_cost: 0.057729083665338646
# 9, 9_heating_heater_quality_product: 0.021792828685258964
# 10, 10_flipkart_installation_installationbad_flip: 0.003824701195219122
# 11, 11_geyser_gyser_optionservice_service: -0.05203187250996016
# 12, 12_installation_delivery_installationgreat_offline: -0.01601593625498008
# 13, 13_purchasing_purchase_month_products: -0.07406374501992032
# 14, 14_installation_delivery_installed_install: 0.011872509960159362
# 15, 15_delivery_deliveryvery_flipkart_deliveryman: 0.04780876494023904
# 16, 16_bajaj_service_worked_useful: 0.0019521912350597623
# 17, 17_technician_service_certified_useful: 0.0398406374501992
# 18, 18_flipkart_tvfridge_purchase_products: 0.005936254980079681
#
#   ---------------------
#
# BAJAJ 17 L Solo Microwave Oven being processed
# -1, -1_litres_microwave_quality_price: 0.18471337579617833
# 0, 0_microwave_oven_cooking_heating: 0.6225276567214213
# 1, 1_delivery_quality_flipkart_product: 0.5826349312772375
# 2, 2_useful_affordable_use_using: 0.07643312101910828
#
#   ---------------------
#
# BAJAJ 3 L Instant Water Geyser being processed
# -1, -1_gyser_pipes_shops_price: 0.020833333333333332
# 0, 0_installation_bajaj_installed_geyser: 0.16477272727272718
# 1, 1_geyser_gyser_heating_bathing: -0.35606060606060613
# 2, 2_buyworking_problems_working_months: -0.08901515151515152
#
#   ---------------------
#
# BAJAJ Crest Neo 1200 mm 3 Blad being processed
# -1, -1_fan_quality_air_ac: -0.2546933667083855
# 0, 0_fan_fans_speed_rating: 0.08573216520650813
# 1, 1_speed_speedbest_slow_fast: -0.03254067584480601
# 2, 2_fan_flipkart_flipkar_bajajs: 0.18022528160200252
# 3, 3_quality_products_product_productu: -0.06195244055068836
# 4, 4_noise_speed_noiseoverall_slow: -0.045682102628285357
# 5, 5_fan_noise_fans_quality: 0.026282853566958694
# 6, 6_bajaj_airflowbearing_condenser_air: -0.23529411764705882
#
#   ---------------------
#
# BAJAJ Fx11 Food Factory 600 W  being processed
# -1, -1_bajaj_flipkart_flipcart_processor: -0.18339978252990213
# 0, 0_processor_kitchen_mixer_grinder: 0.4313156940920624
# 1, 1_flipkart_bajaj_service_delivery: -0.1594780717651323
# 2, 2_packaging_delivery_packing_packingabout: 0.12359550561797752
# 3, 3_motor_motorwhat_sectionmotor_machine: -0.006886553098948894
# 4, 4_jar_jars_bajaj_fx10: 0.05472997462848858
# 5, 5_repair_worked_working_service: 0.0
#
#   ---------------------
#
# BOSCH SMS66GW01I Free Standing being processed
# 0, 0_dishwasher_cleaning_dishes_rinse: 1.2675814751286447
# 1, 1_customer_repair_flipkart_service: -0.7512864493996572
#
#   ---------------------
#
# Bajaj DX 2 LW Dry Iron being processed
# -1, -1_design_product_very_productits: -0.11319073083778967
# 0, 0_iron_ironing_quality_buy: 0.09358288770053474
# 1, 1_flipkart_flipcart_flipcartthats_delivery: 0.2647058823529411
# 2, 2_lightweight_weight_weighted_weightsmall: 0.19607843137254896
# 3, 3_warranty_products_product_reviews: -0.15151515151515152
# 4, 4_heating3after_heating_temperature_heated: -0.15508021390374332
# 5, 5_bajaj_bajajs_brand_flipkart: 0.03654188948306594
# 6, 6_small_size_worth_comfortable: -0.03208556149732621
# 7, 7_quality_review_sturdy_performance: 0.01336898395721925
#
#   ---------------------
#
# Bajaj GX1 500 W Mixer Grinder being processed
# -1, -1_reliable_electrical_flipkart_quality: -0.010210210210210213
# 0, 0_product_quality_flipkart_very: 0.45045045045045096
# 1, 1_mixer_grinder_grinding_jar: -0.1375375375375373
# 2, 2_jars_jar_mixer_container: -0.0897897897897898
# 3, 3_bajaj_flipkart_quality_brand: 0.0858858858858859
# 4, 4_smoke_jars_mixer_jar: -0.24444444444444446
#
#   ---------------------
#
# Bella vita organic Luxury Unis being processed
# -1, -1_fragrance_fragrances_perfume_perfumes: 0.36507936507936506
# 0, 0_perfume_fragrance_fragrances_perfumes: 0.27568922305764404
# 1, 1_fragrance_perfume_fragrances_perfumes: 0.18045112781954886
# 2, 2_perfume_perfumes_fragrances_perfumetheseperfume: 0.06934001670843776
# 3, 3_perfume_perfumes_perfumepeople_perfumei: 0.04553049289891395
# 4, 4_perfume_products_productactuallyfragness_product: -0.27610693400167086
# 5, 5_perfumes_perfume_fragrance_smell: 0.11904761904761904
# 6, 6_fragrance_perfume_perfumesmell_bella: -0.01796157059314954
# 7, 7_perfume_perfumeproduct_fragrance_perfumes: -0.29991645781119464
# 8, 8_fragrance_smell_smells_review: -0.3078529657477026
#
#   ---------------------
#
# Boys Full Sleeve Solid Hooded  being processed
# 0, 0_fleece_sweatshirt_jacket_material: 0.2857142857142857
# 1, 1_quality_cheap_1617_size: 0.1111111111111111
# 2, 2_fibers_fabric_bubbles_bubbling: -0.38001867413632123
# 3, 3_fabric_fabricperfect_woolen_jacket: -0.01307189542483661
# 4, 4_flipkart_great_buy_thanks: 0.20634920634920634
# 5, 5_winters_winter_fabric_cloth: 0.06349206349206349
# 6, 6_child_father_mona_dr: 0.14285714285714285
# 7, 7_quality_warm_soft_thank: 0.19047619047619047
# 8, 8_fabric_colour_color_cloth: 0.15873015873015872
# 9, 9_sizedesinecolour_size_quality_extraordinaryfantastic: 0.15873015873015872
#
#   ---------------------
#
# Butterfly Rapid 750 W Juicer M being processed
# -1, -1_jars_mixer_jar_juicer: -0.039211063963539246
# 0, 0_flipkart_delivery_product_quality: -0.1232909005186251
# 1, 1_mixer_mixerit_mixersoverall_quality: 0.05563413484205563
# 2, 2_juicer_juicers_juice_juices: 0.014026402640264012
# 3, 3_jars_jar_juicer_standardwashers: -0.01972340091151973
# 4, 4_grinder_mixer_jar_jars: 0.04369008329404368
# 5, 5_mixer_juicer_quality_productmust: 0.033749803551783746
# 6, 6_grindingotherwise_grinder_grind_grinding: 0.004046833254754044
# 7, 7_jars_jar_quality_stainless: 0.04365079365079365
# 8, 8_grinder_mixer_grinding_grind: 0.023848813452773846
# 9, 9_grinder_grinding_burntafter_blade: -0.10891089108910891
# 10, 10_blade_blades_sharpen_sharp: -0.12871287128712872
# 11, 11_jars_jar_grinding_grinds: -0.0475011786892975
# 12, 12_motor_rpm_mixer_speed: 0.004007543611504006
# 13, 13_grinder_juicer_mixer_maulinex: 0.03571428571428571
# 14, 14_jars_jarsthe_shipping_delivery: 0.023809523809523808
# 15, 15_jars_jar_lid_plastic: -0.0475011786892975
# 16, 16_grinding_quality_product_satisfiedratings1: 0.03767876787678768
#
#   ---------------------
#
# Butterfly Rapid Plus 750 W Mix being processed
# -1, -1_grinder_grinding_starterd_motor: -0.08721670486376369
# 0, 0_product_flipkart_products_flipcart: 0.38197097020626386
# 1, 1_grinder_mixer_grinding_grind: -0.2910618792971736
# 2, 2_jars_jar_grinder_flipkart: -0.1291061879297174
# 3, 3_jars_jarsnot_jar_lid: -0.15877259994907056
# 4, 4_mixer_jar_qualitymotor_jars: -0.009039979628214935
# 5, 5_noisy_noise_sound_loud: 0.0492742551566081
# 6, 6_jars_jar_quality_jarsthankyou: 0.14705882352941174
# 7, 7_jars_jar_quality_stainless: 0.03284950343773873
#
#   ---------------------
#
# Butterfly Rapid Plus Wet Grind being processed
# -1, -1_heating_smell_drum_hot: -0.04365079365079365
# 0, 0_grinder_scrapper_grinding_scrap: 0.035714285714285726
# 1, 1_delivery_delivered_quality_purchase: 0.49603174603174616
#
#   ---------------------
#
# Butterfly Rhino 2 Ltr Wet Grin being processed
# 0, 0_motor_grinder_quality_grind: -0.9107692307692308
# 1, 1_flipkart_product_carton_delivery: 1.304615384615385
#
#   ---------------------
#
# Butterfly Rhino Plus Wet Grind being processed
# -1, -1_grinding_durability_grindes_drum: 0.02272727272727272
# 0, 0_packing_delivery_goods_quality: 0.38636363636363646
# 1, 1_grinder_grind_grinding_grinds: 0.2727272727272727
# 2, 2_grinder_grind_butterfly_noise: -0.20454545454545453
# 3, 3_grinding_grind_grinders_grinder2: -0.5681818181818181
#
#   ---------------------
#
# CMerchants Multi Organiser BLu being processed
# 0, 0_shelf_sturdy_books_stand: 0.12537037037037058
# 1, 1_pipe_pipes_durable_bend: -0.023518518518518515
#
#   ---------------------
#
# Canon EOS 3000D DSLR Camera 1  being processed
# -1, -1_camera_dslr_photography_cameras: 0.3765432098765433
# 0, 0_camera_dslr_photography_canon: 0.7611111111111138
# 1, 1_delivery_flipkart_shipment_flipkrt: 0.17777777777777776
# 2, 2_memorycard_sdcard_card_memory: 0.05
# 3, 3_1500d_1200d_13000d_1300d: -0.01049382716049383
# 4, 4_recording_audio_recordingthey_dslr: -0.08580246913580247
# 5, 5_worth_value_quality_price: 0.046296296296296294
# 6, 6_camera_flash_flashes_capture: -0.16543209876543213
# 7, 7_charging_charger_charge_chargedand: -0.07962962962962963
# 8, 8_camera_date_package_packaging: -0.01666666666666667
# 9, 9_cheap_rate_price_worth: 0.027777777777777776
#
#   ---------------------
#
# Canon PG 745S Black Ink Cartri being processed
# -1, -1_ink_printed_quality_capacity: -0.15789473684210525
# 0, 0_copies_printed_ink_print: 0.881578947368421
# 1, 1_printing_print_printer_printed: -0.756578947368421
# 2, 2_printer_cartridges_printing_cartridge: -0.02631578947368418
#
#   ---------------------
#
# Catvision CSR401HP WIFI Media  being processed
# -1, -1_tv_television_youtube_viewing: 0.10557491289198609
# 0, 0_channels_channel_satellite_wifi: 0.494076655052265
# 1, 1_quality_youtube_qualityremort_video: 0.17421602787456444
# 2, 2_prostitutedthare_prostitutions_casting_defective: -0.1271777003484321
# 3, 3_youtube_5tubicast_tubicast_videos: 0.038327526132404185
# 4, 4_dish_boxthanks_box_boxmobile: 0.16411149825783972
# 5, 5_defective_box_problem_setup: -0.275609756097561
# 6, 6_wifi_reboot_restart_wi: -0.13066202090592335
# 7, 7_hd_tv_quality_dish: 0.06480836236933799
# 8, 8_wifi_quality_loading_mobile: -0.13066202090592335
# 9, 9_mpegg_quality_box_hd: 0.10975609756097561
#
#   ---------------------
#
# Crompton 75 L Desert Air Coole being processed
# -1, -1_cooling_ventilation_cooler_humidity: 0.1925465838509318
# 0, 0_cooling_coolers_cooler_air: 0.07287784679089031
# 1, 1_cooling_cooler_performance_quality: 0.21573498964803323
# 2, 2_cooling_cooler_coolers_humid: 0.06501035196687373
# 3, 3_cooling_coolingbut_cooler_coolerairthrow: 0.08861283643892343
# 4, 4_ventilation_humidity_ambience_roomguys: 0.043892339544513465
# 5, 5_pump_motor_roomwater_descriptionhoweverwater: -0.20372670807453414
# 6, 6_delivery_cooling_packaging_delivered: 0.09440993788819879
# 7, 7_air_quality_fan_design: 0.0062111801242236
# 8, 8_crompton_quality_cromption_brand: 0.06459627329192547
# 9, 9_water_honeycomb_pump_draining: -0.06832298136645963
# 10, 10_cooling_coolers_cooler_coolerits: 0.0463768115942029
# 11, 11_cooler_flipkart_flipkarts_flipkartmy: -0.07204968944099378
# 12, 12_cooling_ventilation_cooler_ac: 0.04927536231884058
# 13, 13_plastic_quality_design_leakages: 0.01946169772256729
# 14, 14_cooling_cooler_fan_air: -0.05341614906832299
# 15, 15_cooler_inlet_pump_cold: 0.007867494824016562
# 16, 16_coolers_coolerpump_cooler_rooms: 0.04057971014492753
# 17, 17_defective_flaps_louvers_problem: -0.03229813664596273
# 18, 18_flipkart_repair_replacement_defected: -0.0587991718426501
# 19, 19_scratches_scratch_product_deliveredproduct: -0.0016563146997929622
# 20, 20_cooling_ventilation_coolers_cooler: 0.03188405797101449
# 21, 21_2months_months_product_using: 0.020289855072463767
# 22, 22_cooling_temp_avg_quality: -0.03146997929606626
# 23, 23_courier_flipkart_flipcart_delivery: -0.007453416149068321
# 24, 24_wheel_wheels_defective_quality: -0.08571428571428573
# 25, 25_delivery_retail_product_packing: -0.0016563146997929622
# 26, 26_cromptonpros_airflow_motors_motor: 0.001242236024844719
# 27, 27_weatherproduct_weathermake_wind_quality: 0.014492753623188406
# 28, 28_cooler_ventilation_rangeair_range: 0.02318840579710145
#
#   ---------------------
#
# Crompton Hill Briz Deco 1200 m being processed
# 0, 0_motor_fan_quality_speed: -0.236013986013986
# 1, 1_packaging_quality_delivery_deliveryall: 0.2272727272727273
#
#   ---------------------
#
# DLink DIR615 Wireless N 300 Ro being processed
# -1, -1_router_wireless_flipkart_delivery: 0.05000000000000003
# 0, 0_router_wifi_broadband_antenna: 0.3482758620689655
# 1, 1_quality_delivery_flipcart_flipkart: -0.24022988505747125
# 2, 2_range_rangewi_rangeit_wifi: 0.14655172413793102
# 3, 3_router_routersi_routers_300mbps: 0.045402298850574715
# 4, 4_router_netgear_route_cable: -0.08045977011494251
# 5, 5_routers5_router_wificons1_network: 0.13793103448275865
# 6, 6_connectivity_dlink_mbps_internet: 0.028160919540229888
# 7, 7_router_wifi_wifitill_disconnecting: -0.12471264367816091
#
#   ---------------------
#
# DLink DIR825 AC1200 WiFi Gigab being processed
# -1, -1_router_wifirange_5g_firmware: 0.010955569080949482
# 0, 0_router_routers_wifi_network: 0.1679853925745587
# 1, 1_rangewifi_range_firmware_router: -0.3493609251369446
# 2, 2_5g_2g_satisfied_product: 0.3073645769933049
# 3, 3_connectivity_signal_80211ac_mbps: 0.2751065124771759
# 4, 4_5ghz_24ghzsame_24ghz_router: 0.008520998174071814
#
#   ---------------------
#
# Dallao Waterproof Remote Contr being processed
# -1, -1_signal_remote_powerful_battery: 0.2823529411764706
# 0, 0_charging_battery_charge_batteries: -0.1274509803921569
# 1, 1_car_speed_vehicle_goodspeed: 0.001960784313725497
# 2, 2_smaller_size_small_quality: -0.19019607843137254
#
#   ---------------------
#
# Dhawani Skating Shoe have diff being processed
# 0, 0_skate_wheel_wheels_skates: -0.11666666666666663
# 1, 1_colour_blue_color_red: 0.13333333333333333
#
#   ---------------------
#
# Divinext 1 week Pill Medicine  being processed
# -1, -1_closing_tight_boxes_breaks: -0.24358974358974358
# 0, 0_medicines_medicine_multivitamins_medications: 0.2692307692307694
# 1, 1_boxes_box_quality_lid: -0.10256410256410253
# 2, 2_useful_quality_worth_itemproduct: 0.6153846153846154
#
#   ---------------------
#
# ENVY Combo Perfume For Men 60M being processed
# 0, 0_fragrance_perfume_smell_lasting: -0.11111111111111105
# 1, 1_70ml_60ml_60ml60ml_70ml70ml: -0.17676767676767674
#
#   ---------------------
#
# EUREKA FORBES Trendy Zip Dry V being processed
# -1, -1_suction_vacuum_air_motor: -0.055129609346476816
# 0, 0_motor_product_heating_quality: 0.01058780576852866
# 1, 1_cleaner_vacuum_cleaners_cleaning: 0.24059875867104785
# 2, 2_packaging_delivery_packing_goodpacking: 0.16867469879518074
# 3, 3_repairreplacenever_faulty_warranty_productstop: -0.41840087623220157
# 4, 4_cleaning_cleaner_vaccum_clean: -0.024461482292807604
# 5, 5_suction_accessories_cheap_2400rs: -0.006571741511500542
# 6, 6_cleanliness_dust_dusts_cleans: 0.14457831325301204
# 7, 7_vacuum_cleaner_quality_eureka: 0.10843373493975905
# 8, 8_length_cord_longer_wire: -0.00036509675063891786
# 9, 9_dustbag_dust_cleanercons1_use: 0.06024096385542169
#
#   ---------------------
#
# Ebee Engineered Wood Computer  being processed
# -1, -1_assembling_assemble_alignment_engineered: 0.2833333333333333
# 0, 0_assembling_assemble_quality_wood: -0.3476190476190476
# 1, 1_table_assembling_assemble_desk: 0.9642857142857144
# 2, 2_installation_install_customer_quality: -0.5285714285714285
#
#   ---------------------
#
# Eurodomo Hood Indigo PRO HC SC being processed
# 0, 0_quality_installation_features_review: 0.6396396396396403
# 1, 1_chimney_exhaust_duct_stove: 0.22612612612612615
#
#   ---------------------
#
# F FERONS Wireless rechargeable being processed
# -1, -1_speaker_subwoofer_fm_quality: 0.06791171477079797
# 0, 0_backup_battery_soundtqqflipkart_quality: -0.3786078098471986
# 1, 1_speaker_quality_sound_audio: 0.7215619694397282
# 2, 2_speaker_sound_charging_volume: -0.4295415959252971
#
#   ---------------------
#
# FLIPZON Baby 6 Shelve Unbreaka being processed
# -1, -1_quality_rack_chains_cabinets: 0.10416666666666664
# 0, 0_quality_product_retail_genuine: 0.21726190476190477
# 1, 1_zips_zip_woven_cloth: -0.27380952380952384
# 2, 2_spacious_quality_fabrics_wardrobe: 0.3333333333333333
# 3, 3_clothing_garment_clothes_cloths: 0.20833333333333331
# 4, 4_wheels_wheel_flipcart_reliable: -0.03869047619047619
#
#   ---------------------
#
# Fashion Tree TW12 Steel Toe Ge being processed
# -1, -1_comfortable_wearing_unuseful_no: -0.3333333333333333
# 0, 0_shoe_shoes_sole_foot: -0.8525641025641026
# 1, 1_quality_product_review_ordered: 0.7435897435897436
#
#   ---------------------
#
# Flipkart Perfect Homes Dalton  being processed
# -1, -1_average_productgood_frequentlycomfortabledont_light: 0.046511627906976744
# 0, 0_table_sturdy_quality_desk: -0.339892665474061
# 1, 1_table_study_shelves_storage: 0.17173524150268335
# 2, 2_table_cabinets_cabinet_fabrication: -0.014311270125223624
#
#   ---------------------
#
# Flipkart Perfect Homes Phonox  being processed
# 0, 0_quality_height_installation_satisfied: -0.3073593073593072
# 1, 1_tv_unit_hardware_installation: -0.010822510822510845
#
#   ---------------------
#
# Flipkart Perfect Homes Studio  being processed
# -1, -1_quality_weight_linen_material: -0.4825396825396825
# 0, 0_assembling_sturdy_assemble_fabric: -0.047619047619047505
# 1, 1_assemble_quality_durable_shelf: 0.876190476190476
#
#   ---------------------
#
# Flipkart Perfect Homes Webster being processed
# -1, -1_cabinet_assembledit_delivery_designed: 0.01834862385321101
# 0, 0_quality_installation_satisfied_install: -0.7092142002393298
# 1, 1_tv_quality_height_cabinet: 0.3258875149581173
#
#   ---------------------
#
# Flipkart SmartBuy 10W Fast Cha being processed
# 0, 0_charger_adapter_charge_chargerr: -1.351648351648351
# 1, 1_charger_charging_chargers_discountbut: 0.40659340659340665
# 2, 2_charging_charger_charge_quality: 0.17582417582417584
# 3, 3_charger_start_3rd_bestwire: 0.46153846153846156
#
#   ---------------------
#
# Flipkart SmartBuy CFXB15 Elect being processed
# -1, -1_switch_automatic_wire_wires: -0.17929482370592648
# 0, 0_quality_product_useful_is: 0.6781695423855963
# 1, 1_rice_cooking_cooker_cook: 0.2003000750187547
# 2, 2_bowls_bowl_cooking_cook: 0.19504876219054762
# 3, 3_cook_cooking_cooker_cookingso: -0.2955738934733684
# 4, 4_flipkart_ricecooker_smartbuy_refunding: -0.12378094523630907
# 5, 5_cooker_dish_cook_cooking: -0.18829707426856715
#
#   ---------------------
#
# Flipkart SmartBuy CFXB18 Elect being processed
# -1, -1_flipkart_cooker_flipcart_product: 0.21882514599793887
# 0, 0_cooker_cook_cooking_rice: 0.271384403984885
# 1, 1_quality_useful_product_recommend: 0.31638612160769497
# 2, 2_rice_cooker_cooking_cook: -0.16695293713500517
# 3, 3_flipkart_flipcart_imageflipkart_damaged: 0.12779113706630024
# 4, 4_quality_qualitystrength_durable_compare: -0.07317073170731708
# 5, 5_charger_charge_chord_charging: -0.13981449673651666
# 6, 6_switch_problem_warranty_working: -0.1989007214015802
# 7, 7_cooker_cooking_rice_cook: -0.045001717622810036
#
#   ---------------------
#
# Flipkart SmartBuy ISI Mark Sho being processed
# 0, 0_heating_water_boiling_heater: 0.4078431372549022
# 1, 1_quality_reviews_performance_product: -0.08431372549019608
#
#   ---------------------
#
# Furnifry Wooden TV Entertainme being processed
# -1, -1_15k_worth_small_ot: -0.06060606060606061
# 0, 0_installation_assembling_install_built: -0.07103825136612021
# 1, 1_tv_tvs_furnitureplease_installation: 0.3402881271733731
# 2, 2_shelves_delivery_packing_quality: -0.10233482364629903
# 3, 3_product_products_worth_price: 0.3114754098360656
# 4, 4_quality_poor_comparison_shine: -0.3283656234475907
# 5, 5_quality_sturdy_delivery_overall: 0.11475409836065574
# 6, 6_wall_mounting_mount_screws: -0.030303030303030297
# 7, 7_flipkart_flipcart_furniture_quality: -0.022851465474416285
#
#   ---------------------
#
# Furnifry Wooden Wall Mounted T being processed
# -1, -1_wood_furniture_sturdy_quality: -0.03720930232558138
# 0, 0_quality_product_products_advertised: 0.031627906976744176
# 1, 1_quality_installation_built_diy: 0.18232558139534877
# 2, 2_tva_tvstarting_tv_tvs: 0.3088372093023256
# 3, 3_shelves_quality_packing_drawer: -0.02046511627906976
# 4, 4_installation_mounting_wall_mounted: -0.06325581395348838
#
#   ---------------------
#
# Futurekart Ear Plugs Soft Sili being processed
# -1, -1_ear_ears_earsseller_noise: 0.18035190615835778
# 0, 0_noise_noiseusefulmay_noisy_sound: -0.38269794721407624
# 1, 1_ear_ears_earpiece_hearing: -0.2609970674486804
# 2, 2_plugs_ear_soft_softer: 0.19941348973607037
#
#   ---------------------
#
# GLOBAL GREEN Dragon TreeHybrid being processed
# -1, -1_plants_plant_soil_packaging: -0.6078431372549019
# 0, 0_plants_planted_plant_varieties: 0.5147058823529412
# 1, 1_product_quality_bad_grow: -0.4215686274509802
#
#   ---------------------
#
# Glemora ISO Certified 100 Unit being processed
# 0, 0_mask_maskfor_maskno_quality: 0.5166666666666668
# 1, 1_quality_products_product_productdont: -0.7333333333333331
#
#   ---------------------
#
# Google Chromecast 3 Media Stre being processed
# -1, -1_android_mobile_streaming_tv: 0.09887377504753542
# 0, 0_chromecast_streaming_tv_chrome: 0.2974989030276437
# 1, 1_tv_tvs_hdmi_samsung: 0.33962264150943394
# 2, 2_chromecast_tv_hdmi_tvworks: 0.2452830188679245
# 3, 3_chromecast_hotspot_wifi_router: -0.15079713324557553
# 4, 4_tv_casting_android_apps: 0.1761006289308176
# 5, 5_delivery_service_delivering_flipkart: 0.11949685534591195
# 6, 6_hdmi_tv_screen_android: 0.07108380868802106
# 7, 7_streaming_stream_streams_tv: -0.11247623226561358
# 8, 8_streaming_streamingbut_chromecast_buffering: 0.041538686558432056
# 9, 9_netflix_wifi_tv_youtube: 0.008190726927014766
# 10, 10_restarts_warranty_reset_repair: -0.313002778996636
# 11, 11_flipkart_device_complaint_subscription: 0.014480035103115407
# 12, 12_chromecast_firestick_alexa_chrome: 0.07795816878747988
# 13, 13_chromecast_jio_streaming_jiocinema: -0.038320900979961964
#
#   ---------------------
#
# Google Nest Mini 2nd Gen with  being processed
# -1, -1_bluetooth_speaker_mobile_sound: -0.032048681541582164
# 0, 0_speaker_bluetooth_useful_device: 0.3180527383367143
# 1, 1_mini_nest_speaker_android: -0.28600405679513186
# 2, 2_pixel_purchasing_device_review: 0.24705882352941175
# 3, 3_alexa_quality_voice_siri: 0.0032454361054766734
# 4, 4_bluetooth_wifi_device_connectivity: -0.3793103448275862
#
#   ---------------------
#
# Greenery Hub Home Garden Flowe being processed
# -1, -1_seeds_germinated_seed_lotus: 0.02425373134328359
# 0, 0_seeds_seed_germination_packaging: -0.2845149253731343
# 1, 1_seeds_seed_flowers_plants: -0.3805970149253732
# 2, 2_germination_seeds_germinate_germinated: 0.11940298507462686
# 3, 3_seeds_planted_germinate_blooming: 0.05970149253731343
# 4, 4_germination_germinating_seeds_germinated: -0.24999999999999997
# 5, 5_seeds_seed_germination_flower: 0.13432835820895522
# 6, 6_seeds_seed_leafes_garden: 0.14925373134328357
# 7, 7_seeds_seed_sproutings_seedseach: 0.027052238805970144
#
#   ---------------------
#
# HP 678 Black Ink Cartridge being processed
# -1, -1_cartridges_ink_quality_printer: -0.044134727061556314
# 0, 0_cartridge_cartridgei_printer_ink: -0.5888501742160278
# 1, 1_printing_printer_printers_cartridge: 0.1997677119628339
# 2, 2_printerbut_printer_printers_printersim: -0.4494773519163763
# 3, 3_delivery_packaged_flipkart_packaging: 0.4878048780487805
# 4, 4_ink_print_paper_hp: 0.36353077816492446
# 5, 5_genuine_satisfied_product_seller: 0.3414634146341463
#
#   ---------------------
#
# HP 680 Black Ink Cartridge being processed
# -1, -1_cartridge_printers_printer_cartridgewhen: 0.15576923076923077
# 0, 0_cartridges_cartridge_printer_hp: 0.08846153846153841
# 1, 1_flipkart_delivery_priceoverall_seller: 0.5173076923076924
# 2, 2_printer_cartridge_printed_ink: -0.8756410256410259
# 3, 3_printing_prints_printer_cartridge: -0.0717948717948718
#
#   ---------------------
#
# Haier 65 kg 5 star Ariel Wash  being processed
# -1, -1_pipe_cost_inlet_pipes: 0.11000000000000001
# 0, 0_washing_wash_machine_machines: 0.15290322580645163
# 1, 1_installation_instalation_delivery_delivered: 0.14645161290322586
# 2, 2_haier_quality_rangethank_products: 0.29
# 3, 3_timer_displayeasy_display_screen: 0.09000000000000001
# 4, 4_quality_performance_reliable_worth: 0.14
# 5, 5_months_quality_repair_month: 0.14225806451612902
#
#   ---------------------
#
# Hindware Nevio Plus 60  Auto C being processed
# -1, -1_vibration_reviews_10500_design: 0.055672268907563036
# 0, 0_flipkart_hindware_quality_products: -0.056722689075630134
# 1, 1_chimney_cooking_kitchen_burner: 0.059873949579831984
# 2, 2_pipe_exhaust_duct_installation: 0.03571428571428574
# 3, 3_installationthe_installation_install_instalation: -0.1848739495798319
# 4, 4_installation_installing_installed_product: 0.10609243697478993
# 5, 5_sensor_motion_lifehindware_exhaust: 0.08928571428571429
# 6, 6_delivery_packaging_installation_arrived: 0.10294117647058824
# 7, 7_noise_louder_voice_functionality: 0.044117647058823525
# 8, 8_leakage_leaking_oil_grease: -0.05777310924369748
# 9, 9_suction_noise_noisy_blower: -0.049369747899159655
#
#   ---------------------
#
# Hindware Ripple 90 Auto Clean  being processed
# -1, -1_quality_hindware_flipkart_feedback: -0.0380952380952381
# 0, 0_performance_noise_sound_recommend: 0.3238095238095238
# 1, 1_installation_700installed_installed_delivery: 0.4047619047619047
# 2, 2_chimney_chimneydelivery_chimneycan_smoke: 0.34285714285714286
# 3, 3_pipe_duct_exhaust_plumbers: -0.01428571428571429
#
#   ---------------------
#
# Home Full Bliss Engineered Woo being processed
# 0, 0_installation_quality_experience_product: -0.28137651821862364
# 1, 1_tv_cabinets_sturdy_drawers: 0.680161943319838
#
#   ---------------------
#
# I Kall IK22 40 W Bluetooth Hom being processed
# 0, 0_quality_bass_sound_speaker: 0.6789297658862875
# 1, 1_speaker_speakers_woofer_sound: -1.0668896321070231
#
#   ---------------------
#
# IFB 23 L Convection Microwave  being processed
# 0, 0_microwave_oven_convection_flipkart: 0.8755364806866925
# 1, 1_flipkart_quality_delivery_installation: 0.7000476871721493
#
#   ---------------------
#
# IFB Neptune VX Free Standing 1 being processed
# -1, -1_dishwasher_dishwashing_dishwa_dishes: 0.30666666666666664
# 0, 0_flipkart_complaints_demo_delivery: 0.153939393939394
# 1, 1_dishwasher_cookware_dish_washer: 0.3066666666666667
# 2, 2_utensils_cleaning_spoons_cleans: 0.32
# 3, 3_machine_prewash_wash_functioning: 0.002424242424242412
# 4, 4_cleaning_detergent_dishwashergreat_rinse: 0.13333333333333333
# 5, 5_dishwasher_dish_dishes_washer: 0.01575757575757576
#
#   ---------------------
#
# IFB Neptune VX Plus Free Stand being processed
# -1, -1_cleaning2now_maidconsif_washing_clean: 0.07692307692307693
# 0, 0_product_flipkart_flipcart_productperformance: -0.045454545454545414
# 1, 1_dishwasher_detergent_cleaning_cutlery: 0.2744755244755245
# 2, 2_washer_washing_afterwash_wash: -0.33391608391608385
# 3, 3_dishwashers_dishwasher_dishes_utensils: 0.5279720279720279
# 4, 4_flipkart_dishwasher_inletoutlet_service: 0.3216783216783217
#
#   ---------------------
#
# Inalsa Easy Prep 800 W Food Pr being processed
# -1, -1_appliances_flipkart_product_makercompare: -1.072727272727273
# 0, 0_blades_bladeattachment_blade_chopping: 0.7590909090909089
# 1, 1_performance_product_rating_qualitywise: 0.13636363636363638
#
#   ---------------------
#
# Inalsa Fiesta Lx 650 W Food Pr being processed
# -1, -1_motor_machine_blades_kitchen: 0.21428571428571433
# 0, 0_defective_flipkart_customer_replacement: -0.5866828087167071
# 1, 1_processor_grinder_blades_kitchen: 0.5000000000000001
# 2, 2_jars_spices_jar_juicer: -0.06949152542372883
# 3, 3_inalsa_inaka_motor_service: -0.20605326876513316
# 4, 4_chop_slicing_vegetables_slicingwhat: -0.03656174334140436
# 5, 5_juicer_repair_cutter_broken: -0.0847457627118644
# 6, 6_inalsa_processor_processors_grinder: 0.06610169491525424
#
#   ---------------------
#
# Inalsa Inox 1000 1000 W Food P being processed
# 0, 0_jar_grinder_quality_lid: 0.010162601626016253
# 1, 1_review_flipkart_flipcart_delivery: 0.22764227642276424
#
#   ---------------------
#
# Inalsa fiesta 650 W Food Proce being processed
# -1, -1_quality_reliable_replacement_material: -0.009523809523809532
# 0, 0_grinder_grinding_processor_blade: 0.49999999999999994
# 1, 1_juicer_blades_blade_motor: -0.05714285714285712
# 2, 2_flipcart_flipkart_quality_flipkarts: -0.05238095238095237
# 3, 3_products_quality_productbut_product: -0.32380952380952377
#
#   ---------------------
#
# Infinix 10W Quick Charger comb being processed
# 0, 0_chargingrate_chargingalso_charger_charging: -0.14536340852130325
# 1, 1_charger_charging_purchase_purchased: 0.37092731829573933
# 2, 2_infinix_product_performance_productplease: -0.5463659147869674
# 3, 3_flipkart_products_received_urgently: -0.020050125313283207
# 4, 4_charger_infinix_charge_s4: 0.2857142857142857
# 5, 5_charger_chargeing_charge_charges: 0.23809523809523808
#
#   ---------------------
#
# KENT Ace 8 L RO  UV  UF  TDS W being processed
# -1, -1_water_filter_serviced_complaints: 0.09599728629579375
# 0, 0_sediment_filter_purification_water: 0.559362279511533
# 1, 1_purifier_filter_filters_filtered: -0.06309362279511531
# 2, 2_valve_service_installation_replaced: -0.45522388059701496
# 3, 3_flipkart_flipkartthe_installation_installed: 0.027815468113975582
# 4, 4_tds_water_meter_dysentery: -0.14484396200814115
# 5, 5_price_buy_rupees_value: 0.12652645861601086
# 6, 6_uv_tank_prefilter_installation: -0.09871099050203527
#
#   ---------------------
#
# KENT Ace Extra Ace Alkaline 8  being processed
# -1, -1_filtration_filter_pump_tank: -0.0712495914587646
# 0, 0_installation_instalation_installations_service: 0.08432291099248282
# 1, 1_installation_installtion_installed_engineer: 0.29099030395467923
# 2, 2_prefilter_filters_filter_kent: 0.06405926571521951
# 3, 3_purifier_prefilter_filter_delivery: -0.040418346225079005
# 4, 4_uv_tank_water_light: 0.10153611504521189
# 5, 5_water_service_installation_kent: 0.1751824817518248
# 6, 6_kent_systemservice_ro_installation: -0.04641028434469986
# 7, 7_purification_test2water_water_kent: -0.01655953807604315
# 8, 8_water_waterthis_taste_tasteless: 0.08726440788756945
# 9, 9_warranty_filter_defect_replacement: -0.23880597014925375
# 10, 10_leakage_leaking_pipes_water: -0.22420743000326832
# 11, 11_troubleshooting_kent_repaired_service: -0.208955223880597
# 12, 12_purifier_purifiers_purepurifier_budget: 0.06536659766859135
#
#   ---------------------
#
# KENT Aura Portable Room Air Pu being processed
# 0, 0_ionizer_indicator_filter_airits: 0.06060606060606061
# 1, 1_asthma_asthmatic_plants_oxygen: 0.36363636363636354
# 2, 2_installation_register_service_serviceshope: 0.303030303030303
# 3, 3_delhi_sleep_pollution_windows: 0.12121212121212122
# 4, 4_kenti_brand_quality_product: 0.24242424242424243
# 5, 5_switch_flipkart_button_mode: -0.6969696969696969
# 6, 6_lock_flipcarts_safety_broken: -0.5064935064935064
# 7, 7_air_quality_product_feeling: 0.24242424242424243
# 8, 8_filters_filter_two_one: 0.06060606060606061
#
#   ---------------------
#
# LEADER XTREME 26T REAR SUSPENS being processed
# -1, -1_packaging_fittingnot_comfortable_self: -0.1111111111111111
# 0, 0_cycle_chain_sturdy_parts: 0.5952380952380953
# 1, 1_productbreaks_breaks_tyres_broken: -0.7142857142857142
#
#   ---------------------
#
# LIVPURE LIVPEPPROPLUS 7 L RO   being processed
# -1, -1_purifier_cost_purification_quality: 0.20937419520988879
# 0, 0_livpure_livepure_delivery_quality: 0.10687612670615475
# 1, 1_purifier_purify_purifying_water: 0.1359773371104816
# 2, 2_tds_water_waters_purifier: 0.13893896471800155
# 3, 3_prefilter_filter_installed_installation: 0.13610610352819982
# 4, 4_filter_filters_water_prefilter: -0.020087561164048414
# 5, 5_purifier_water_filters_purifiers: 0.15323203708472832
# 6, 6_installation_serviceproduct_quality_installed: 0.05949008498583571
# 7, 7_flipkart_taste_flipcart_product: 0.0651558073654391
# 8, 8_delivery_delivered_installation_deliveryim: 0.0509915014164306
# 9, 9_filtration_purifier_prefilter_packaging: 0.048158640226628906
# 10, 10_purifier_prefilter_purifieractually_filter: 0.0396600566572238
# 11, 11_livpur_livpure_livepure_water: 0.0396600566572238
# 12, 12_purifier_purifiers_livpure_quality: 0.036827195467422094
# 13, 13_purifier_purifieri_reviews_reviewsi: 0.045325779036827205
# 14, 14_tapwater_water_taste_purified: 0.06811743497295905
# 15, 15_warranty_tastequick_month_filter: -0.06824620139067732
# 16, 16_installation_complaint_technician_demo: -0.03129023950553696
# 17, 17_prefilter_filter_tds_qualitytds: 0.028328611898016998
# 18, 18_purifier_purchasepurifier_service_waterits: 0.0113314447592068
#
#   ---------------------
#
# LUMINOUS ZELIO 110012V Ecomm P being processed
# 0, 0_inverter_luminous_mode_watts: 0.7541666666666673
# 1, 1_packaging_quality_packed_seller: 0.2263888888888889
#
#   ---------------------
#
# Lakm Eyeconic Kajal Twin PackD being processed
# -1, -1_texture_product_price_purchase: 0.12101910828025478
# 0, 0_kajal_kajalbut_kajalso_kajalhighly: 0.20985584981562183
# 1, 1_flipkart_flipkarti_quality_product: 0.4394904458598725
# 2, 2_eye_eyes_kajal_eyeconic: -0.6956084478712704
# 3, 3_delivery_packaging_deliver_shipping: 0.11766677841099564
# 4, 4_flipcart_cart_flip_shopping: 0.12101910828025476
# 5, 5_waterproof_lasting_smudge_lasts: 0.10828025477707005
# 6, 6_lakme_brand_quality_products: 0.08280254777070063
# 7, 7_kajal_delivery_date_ordered: 0.06369426751592357
# 8, 8_genuine_original_duplicate_fake: 0.050955414012738856
#
#   ---------------------
#
# Lenovo IdeaPad 3 Ryzen 5 Hexa  being processed
# -1, -1_lenovo_laptop_ideapad_performance: 0.2
# 0, 0_laptop_performance_hp_display: 0.40000000000000013
# 1, 1_ryzen_laptop_performance_audio: 0.2363636363636364
# 2, 2_quality_price_decent_salepackaging: 0.3272727272727273
# 3, 3_display_viewing_angle_performance: 0.21818181818181817
# 4, 4_laptop_booting_restart_cpu: -0.49090909090909085
#
#   ---------------------
#
# Lenovo IdeaPad Gaming Core i5  being processed
# -1, -1_ram_laptop_slot_slots: -0.3508196721311475
# 0, 0_laptop_laptops_performance_brightness: 0.1693989071038251
# 1, 1_laptop_lenovo_gaming_performance: 0.6393442622950821
# 2, 2_performance_quality_battery_batterys: -0.13551912568306007
#
#   ---------------------
#
# MAHARAJA WHITELINE 65 L Desert being processed
# -1, -1_cooling_cooler_ventilation_fan: 0.10553206483439037
# 0, 0_cooling_cooler_rooms_ventilation: 0.2138830162085976
# 1, 1_cooling_coolers_cooler_temperature: 0.048625792811839326
# 2, 2_delivery_flipkart_deliveredthank_deliver: 0.06730091613812543
# 3, 3_cooling_cooler_decent_climate: 0.11627906976744184
# 4, 4_cooling_cooled_cooler_fan: -0.18181818181818182
# 5, 5_wheel_wheels_reviews_powerful: 0.09883720930232556
# 6, 6_cooling_cooler_noise_noisymust: 0.05937279774489078
# 7, 7_product_flipcart_return_flipkart: -0.31589147286821706
# 8, 8_cooling_cooler_inlet_water: 0.10130373502466526
# 9, 9_cleaning_watercable_clean_drain: -0.04897815362931643
# 10, 10_cooling_coolers_cooler_coolerthank: 0.046511627906976744
# 11, 11_cooling_productfan_coolers5_blower: -0.18181818181818182
# 12, 12_700sqrfeet_7500_6200in_bigger: 0.06395348837209303
# 13, 13_wheels_trolley_wheel_cooler: 0.07100070472163496
# 14, 14_cooler_ac_thermocols_appliance: 0.03488372093023256
# 15, 15_cooling_aircooler_sound_cooler: 0.023255813953488372
#
#   ---------------------
#
# MILTON Thermosteel Flip Lid 50 being processed
# -1, -1_useful_leakage_products_product: 0.1789356984478936
# 0, 0_flask_temperature_cold_warm: -0.40776053215077573
# 1, 1_flipkart_product_genuine_quality: 0.09467849223946785
# 2, 2_milton_miltonmilton_products_product: 0.04722838137472283
# 3, 3_750ml_500ml_ml_750: 0.02926829268292683
#
#   ---------------------
#
# MOTOROLA 8 kg Smart WiFi Enabl being processed
# -1, -1_washing_performance_cleaning_quality: 0.3614832535885166
# 0, 0_washing_wash_machine_brand: -0.0755980861244019
# 1, 1_flipkart_installation_installtion_service: -0.01232057416267942
# 2, 2_motorolaworking_motorola_motorolai_motorolamy: 0.14473684210526316
# 3, 3_heater_heating_inbuilt_built: -0.03672248803827751
# 4, 4_demo_delivery_delay_performance: 0.027870813397129185
# 5, 5_installation_installations_instalation_product: 0.046052631578947366
# 6, 6_review_usesoverall_performance_quality: 0.016267942583732056
# 7, 7_price_value_buy_brands: 0.05921052631578947
#
#   ---------------------
#
# MRF ENDORSED  for LightHard Te being processed
# -1, -1_bat_stickers_big_side: 0.0
# 0, 0_bat_ball_tennis_flipkart: 0.4632352941176471
# 1, 1_bat_cover_coverdont_goodbat: -0.19852941176470587
# 2, 2_bat_bating_cricket_broke: -0.875
# 3, 3_bat_hitter_height_16: 0.5294117647058824
# 4, 4_cover_durability_quality_price: -0.06985294117647059
#
#   ---------------------
#
# MSI Core i5 11th Gen  8 GB512  being processed
# -1, -1_laptop_performance_laptops_ram: 0.2176560121765601
# 0, 0_gpu_nvidia_gaming_laptop: 0.13470319634703196
# 1, 1_laptop_battery_screen_defective: -0.47412480974124793
# 2, 2_gpu_performance_144hz_rtx: 0.27473363774733633
# 3, 3_laptop_laptops_processor_msi: 0.19863013698630136
# 4, 4_laptop_performance_backup_battery: 0.1095890410958904
# 5, 5_laptop_60k_quality_90k: 0.17884322678843226
# 6, 6_battery_laptop_charge_charging: 0.2207001522070015
# 7, 7_rtx_3050_laptop_laptops: 0.0821917808219178
# 8, 8_ram_ssd_quality16gb_upgrade: 0.06164383561643835
# 9, 9_laptopdisplay_laptop_laptopsound_keyboard: 0.06164383561643835
#
#   ---------------------
#
# MarQ by Flipkart 18Litre 18L12 being processed
# -1, -1_quality_flipkart_purchase_review: 0.0870247645622602
# 0, 0_baking_oven_baked_otg: 0.0537146843390305
# 1, 1_flipkart_product_products_quality: 0.43573421695151765
# 2, 2_otg_tin_price_is: 0.12295081967213112
# 3, 3_light_lightperformance_lit_bulb: 0.03688524590163935
# 4, 4_timer_clock_reset_timeg: -0.04743634461109174
#
#   ---------------------
#
# MarQ by Flipkart 33Litre 33AOT being processed
# 0, 0_flipkart_otg_quality_affordable: -0.035653650254668934
# 1, 1_oven_baking_baked_bake: 0.3361629881154499
# 2, 2_delivery_deliverymarq_quality_packagingno: 0.3633276740237691
#
#   ---------------------
#
# MarQ by Flipkart 8 kg 5 Star E being processed
# -1, -1_inlet_pipe_plumber_tap: 0.05825242718446601
# 0, 0_washing_wash_detergent_machine: -0.02773925104022219
# 1, 1_flipkart_quality_performance_sale: 0.5006934812760053
# 2, 2_machine_performance_automatic_panasonic: 0.05298196948682384
#
#   ---------------------
#
# Mayne Flying Remote Control RC being processed
# -1, -1_controls_control_uncontrol_toy: -0.09523809523809523
# 0, 0_helicopter_remote_flying_fly: 0.2976190476190477
# 1, 1_quality_worstpls_products_ton3: -0.42857142857142855
#
#   ---------------------
#
# Men  Women Striped Ankle Lengt being processed
# -1, -1_quantity_quality_products_satisfied: -0.2857142857142857
# 0, 0_quality_small_size_product: -0.4857142857142857
# 1, 1_socks_quality_stitches_wash: -0.5999999999999999
# 2, 2_fabrics_quality_cloth_clothes: 0.3571428571428572
#
#   ---------------------
#
# Men 9325 Latest Collection Sty being processed
# 0, 0_shoes_shoe_sole_quality: -0.7678571428571428
# 1, 1_quality_products_product_productin: -0.25
#
#   ---------------------
#
# Men Black Sandal being processed
# -1, -1_strip_quality_layer_holes: -0.05128205128205128
# 0, 0_quality_belt_product_products: 0.1666666666666668
# 1, 1_damaged_rubber_broken_quality: -0.3589743589743589
#
#   ---------------------
#
# Men Cargos being processed
# -1, -1_cargo_cargoits_belt_cargoplease: -0.010907003444316889
# 0, 0_quality_genuine_product_cheapand: -0.4167623421354764
# 1, 1_fabric_cloth_cotton_clothe: -0.021814006888633802
# 2, 2_fitting_fittingand_fittingdislikes_fittingno: -0.06659012629161884
# 3, 3_quality_fiting_comfortable_fit: 0.2026406429391504
# 4, 4_cargo_cargos_fabric_quality: 0.07663605051664753
# 5, 5_pocket_pockets_pants_cargo: -0.10246842709529277
# 6, 6_waist_pants_quality_legs: -0.023536165327210104
#
#   ---------------------
#
# Men Graphic Print Round Neck B being processed
# -1, -1_quality_wear_clothes_product: 0.23076923076923078
# 0, 0_fabric_tshirt_cloth_clothe: -1.0769230769230766
# 1, 1_quality_product_qualitywaste_price: 0.07940446650124075
#
#   ---------------------
#
# Men LPMXT800 Grey Clogs Sandal being processed
# -1, -1_nice_image_this_same: 0.03773584905660377
# ...
# 2, 2_delivery_delivered_quality_products: 0.22222222222222218
# 3, 3_slowness_reading_speeds_write: 0.1977124183006536
# 4, 4_speedy_speeddownloading_sd_speed: 0.17592592592592593
# 5, 5_card_corrupted_cards_unable: -0.5294117647058824
# 6, 6_sandisk_corrupted_storage_sd: -0.3344226579520697
# 7, 7_samsung_purchasing_brand_premium: 0.12962962962962962
# 8, 8_card_memory_cardsi_samsung: 0.1111111111111111
# 9, 9_641gb_storage_transferring_downloading: 0.024509803921568624
# 10, 10_sd_card_delivery_reader: 0.08333333333333333
# 11, 11_faulty_lenovo_months_review: -0.07135076252723312
#
#   ---------------------
#
# SAMSUNG Original 25W  USB C Co being processed
# -1, -1_charger_charge_sunlight_days: -0.3076923076923077
# 0, 0_charger_charging_charge20_25w: -0.7319347319347318
# 1, 1_samsung_genuine_charging_charger: 0.4801864801864799
# 2, 2_charging_a52_m52_charge: 0.21212121212121213
# 3, 3_pixel_charger_charging_charges: 0.15151515151515152
# 4, 4_galaxy_samsung_mobile_m33: 0.18181818181818182
#
#   ---------------------
#
# SSTOYS 3D Fast Modern CarMulti being processed
# 0, 0_remote_defective_flipcart_quality: -1.291666666666667
# 1, 1_car_toy_gift_battery: 0.6458333333333333
#
#   ---------------------
#
# Seagate One Touch with Passwor being processed
# -1, -1_harddisk_hdd_5tb_seagate: -0.0344295991778006
# 0, 0_40mbps_90130mbps_transferring_speeds: -0.047276464542651456
# 1, 1_harddisk_seagate_hdd_disk: -0.048304213771839695
# 2, 2_storage_encryption_disk_backup: 0.27338129496402874
# 3, 3_140mbps_hdd_5tb_mbps: -0.0775950668036999
# 4, 4_storage_hdd_2tb_18tb: 0.11536485097636176
# 5, 5_flipkart_delivery_qualitybest_flipcart: 0.04367934224049333
# 6, 6_performance_speeds_speed_quality: -0.0066803699897225
# 7, 7_hd_harddisk_disk_seagate: 0.07194244604316546
# 8, 8_issuesbut_supported_corrupted_issue: -0.20709146968139772
#
#   ---------------------
#
# Simple Trending PP Collapsible being processed
# -1, -1_pipes_pipesworst_quality_product: -0.20707070707070707
# 0, 0_quality_fabric_durable_cloth: -0.2777777777777778
# 1, 1_product_productnever_helpfull_recommend: 0.4747474747474747
# 2, 2_width_size_smaller_height: -0.606060606060606
# 3, 3_zip_cloth_dress_clothes: -0.3282828282828283
#
#   ---------------------
#
# Singer FM 1409 Electric Sewing being processed
# -1, -1_machine_sewing_delivery_quality: 0.16245614035087722
# 0, 0_sewing_machine_stitching_stitch: 0.3668771929824569
# 1, 1_flipkart_quality_delivery_smoothly: 0.2803508771929824
# 2, 2_needle_needles_sewing_stitchingcover: -0.24449122807017543
# 3, 3_beginner_beginners_beginnerinstruction_learning: 0.07733333333333334
# 4, 4_sewing_machinethe_machine_pico: 0.07466666666666666
# 5, 5_defective_products_product_purchase: -0.11042105263157893
# 6, 6_accessories_product_item_tools: 0.008350877192982456
# 7, 7_stitches_cotton_machine_bobbin: -0.05228070175438596
# 8, 8_demo_installation_demoim_instalation: -0.06294736842105264
# 9, 9_home_household_performance_use: 0.021333333333333333
# 10, 10_valuable_price_6000_buy: 0.029333333333333333
# 11, 11_quality_mechine_product_produced: 0.00035087719298245584
# 12, 12_speed_performance_rate_machine: 0.024
#
#   ---------------------
#
# Sument USB Decoration Star Lig being processed
# 0, 0_covers_room_walls_area: 0.42857142857142844
# 1, 1_lighting_light_dim_dimmed: -1.079365079365079
#
#   ---------------------
#
# TPLink Archer C20 AC WiFi 750  being processed
# -1, -1_router_5g_wifi_ghz: 0.12887887887887892
# 0, 0_5g_5ghz_24ghz_wifi: 0.32757757757757755
# 1, 1_quality_months_month_using: 0.10485485485485488
# 2, 2_router_wireless_connectivity_ghz: 0.18418418418418417
# 3, 3_router_isp_wifi_flipkart: -0.27102102102102105
# 4, 4_range_extender_signal_c50: 0.11486486486486489
# 5, 5_router_wifi_range_firmwarebest: -0.05355355355355354
# 6, 6_router_broadband_wifi_500mbps: 0.16891891891891894
# 7, 7_delivery_delivered_packaging_deliverygo: 0.09134134134134135
# 8, 8_router_wifi_coverage_poorwifi: -0.05030030030030029
# 9, 9_router_75mbps_90mbps_50mbps: 0.06931931931931933
# 10, 10_router_connecting_routeralways_wan: -0.15815815815815815
# 11, 11_wifi_wifis_range_wi: -0.07907907907907907
# 12, 12_signal_signals_quality_decent: -0.0032532532532532493
# 13, 13_100mbps_75mbps_85mbps_200mbps: -0.04704704704704704
#
#   ---------------------
#
# TPLink Archer C6 MUMIMO Gigabi being processed
# -1, -1_router_100mbps_24ghz_wifi: 0.1
# 0, 0_300mbps_100mbps_broadband_5ghz: 0.08333333333333329
# 1, 1_router_5ghz_bandwidth_24ghz: 0.5277777777777778
# 2, 2_router_routers_routerboth_wpa3: 0.04444444444444446
# 3, 3_delivery_delivered_packaging_quality: -0.055555555555555546
# 4, 4_5ghz_wifi_5g_range: 0.09444444444444444
#
#   ---------------------
#
# Thomson Alpha 80 cm 32 inch HD being processed
# -1, -1_quality_tv_tvvery_wifi: 0.13870967741935486
# 0, 0_quality_soundreturning_sound_affordable: 0.38467741935483857
# 1, 1_tvs_tv_thomson_lcd: 0.28548387096774197
# 2, 2_quality_tv_audiopicture_tvlipsing: 0.07338709677419356
# 3, 3_tv_television_quality_affordable: 0.16935483870967746
# 4, 4_installation_instalation_moneybut_moneynext: 0.17983870967741938
# 5, 5_productthe_product_products_cheap: -0.0588709677419355
# 6, 6_tvbut_tv_flipkart_service: -0.2870967741935484
# 7, 7_tv_smart_quality_affordable: 0.11612903225806454
# 8, 8_app_apps_mobile_tv: -0.23064516129032261
# 9, 9_tv_android_linux_os: 0.07096774193548387
#
#   ---------------------
#
# Thomson Kitchen Master Pro MX0 being processed
# 0, 0_kart_productflip_products_quality: 0.0470588235294118
# 1, 1_grinder_grinding_jars_jar: -0.0980392156862745
# 2, 2_jars_lids_jar_lid: -0.11960784313725487
# 3, 3_grinding_grinder_grinders_quality: 0.12058823529411766
# 4, 4_jars_jar_blending_blades: -0.0901960784313725
# 5, 5_blend_jars_mixer_plastic: 0.036274509803921565
#
#   ---------------------
#
# UPC Upgraded Hands Free Squeez being processed
# -1, -1_cleaning_bucket_quality_plastic: -0.10784313725490195
# 0, 0_quality_durable_product_useful: 0.3725490196078432
# 1, 1_mop_mops_cleaning_pad: 0.5882352941176471
# 2, 2_rating_review_qualityand_warranty: -0.9999999999999999
# 3, 3_floor_cleaning_stair_sofa: 0.29411764705882354
#
#   ---------------------
#
# USHA FP 3810 1000 W Food Proce being processed
# -1, -1_motor_grinding_chopping_issue: -0.012820512820512803
# 0, 0_slicer_jars_juicing_jar: 0.7243589743589745
# 1, 1_flipkart_products_complaints_customers: -0.7435897435897434
# 2, 2_processor_dough_performance_quality: 0.3141025641025641
#
#   ---------------------
#
# USHA FP 3811 1000 W Food Proce being processed
# 0, 0_blades_processor_juicer_blade: 0.03134796238244522
# 1, 1_quality_product_delivery_useful: -0.06269592476489033
#
#   ---------------------
#
# VGuard Prime 1150 Pure Sine Wa being processed
# -1, -1_transformer_heat_hot_normal: 0.028985507246376812
# 0, 0_inverter_inverters_cooling_humming: 0.5821256038647343
# 1, 1_service_advertised_review_quality: 0.23913043478260873
# 2, 2_vguard_vguardthis_quality_guard: 0.30434782608695654
# 3, 3_batteryissue_battery_ups_batteryno: -0.060386473429951695
#
#   ---------------------
#
# Voltas Beko DF14W Free Standin being processed
# -1, -1_machine_dishwasher_detergentsthough_salt: 0.029850746268656716
# 0, 0_dishwasher_cleaning_detergent_dish: 0.3625987708516239
# 1, 1_utensils_cleaning_cleaned_detergent: 0.46356453028972766
# 2, 2_flipkart_voltasextremely_voltas_advertised: -0.36611062335381933
# 3, 3_installation_plumbing_free_demo: -0.20632133450395082
#
#   ---------------------
#
# WD 15 TB Wired External Hard D being processed
# -1, -1_usb_hdd_disk_transferring: 0.16816381725103818
# 0, 0_hdd_ssd_harddisk_seagate: 0.3256061045107695
# 1, 1_hdd_disk_corrupted_hd: -0.9313242538394664
# 2, 2_quality_delivery_retailer_flipcart: 0.13339128754950252
# 3, 3_15tb_13tb_360gb_136tb: 0.0643291799478412
# 4, 4_2025mbps_usb20_100120mbps_usb: 0.14778325123152708
# 5, 5_quality_sleek_performance_sturdy: 0.0691586979619434
# 6, 6_104mbps_15tb_120mbps_93mb: 0.10325509514150485
# 7, 7_transfer_speed_mobile_devices: -0.01439196368202453
# 8, 8_72mbps_35mbps_102mbps_1gbps: -0.019414662416690813
# 9, 9_passport_1tb_passportspeed_wd: 0.04926108374384237
# 10, 10_storage_storing_hdd_931gb: 0.06403940886699508
# 11, 11_25mbps_mbps_70mbsthanks_harddrive: 0.00019318072056408696
#
#   ---------------------
#
# Women Regular Fit Black George being processed
# -1, -1_wear_comfortable_zipper_trousers: 0.21212121212121213
# 0, 0_fabric_fabricthe_worthcloth_cloth: -0.48484848484848486
# 1, 1_pants_waist_fit_wear: 0.48484848484848475
# 2, 2_quality_outwear_trouseri_trouser: 0.030303030303030276
#
#   ---------------------
#
# ZEBRONICS ZebVita Plus 16 W Bl being processed
# -1, -1_bass_quality_speaker_sound: 0.34640522875817004
# 0, 0_battery_charging_backup_speaker: -0.3594771241830065
# 1, 1_bass_speaker_speakers_quality: 0.1862745098039216
# 2, 2_fm_radio_antenna_aux: 0.0016339869281046214
# 3, 3_flipkart_flipkarr_flipkar_speaker: -0.07189542483660127
# 4, 4_wattsound_speaker_16w_money16w: 0.004901960784313736
#
#   ---------------------
#
# boAt 18W Power WCD QC3A Charge being processed
# -1, -1_charging_a50charger_charger_chargeriam: -0.031282051282051276
# 0, 0_charging_charger_charge_chargerand: -0.29820512820512823
# 1, 1_charger_charging_charge_chargingit: 0.38307692307692315
# 2, 2_ignition_burner_discontinued_stopped: -0.23923076923076916
# 3, 3_charging_cable_adapter_indiaim: 0.18
# 4, 4_quality_brand_price_product: 0.11435897435897437
# 5, 5_chargingbut_charging_charger_heating: 0.06871794871794873
# 6, 6_cablecable_charger_cable_charging: 0.02871794871794873
# 7, 7_adapter_adaptor_charger_reviews: -0.2564102564102564
# 8, 8_charger_charging_bad_worst: -0.2051282051282051
# 9, 9_charger_charging_charge_20000mah: 0.12000000000000001
# 10, 10_charger_charging_cable_usb: 0.008717948717948723
#
#   ---------------------
#
# boAt Aavante Bar 2000 160 W Bl being processed
# -1, -1_bass_sound_speaker_quality: 0.1006245662734212
# 0, 0_soundbar_bass_sound_music: 0.3219986120749483
# 1, 1_bass_surround_quality_sound: -0.020124913254684074
# 2, 2_bass_sound_bluetooth_aux: -0.09784871616932686
# 3, 3_boataavantebar2000_flipkart_flipkarts_bass: 0.19083969465648853
# 4, 4_soundbar_subwoofer_hdmi_audio: -0.07494795281054824
# 5, 5_bass_speaker_rs4499_boombox: 0.19777931991672448
# 6, 6_subwoofer_soundbar_woofer_bassnever: -0.022206800832755044
#
#   ---------------------
#
# boAt Rockerz 510 Super Extra B being processed
# -1, -1_headphone_headphones_quality_headset: 0.6174719887955173
# 0, 0_bass_headphone_headphones_quality: 0.562850140056021
# 1, 1_bass_boat_headphone_headphones: 0.10906862745098046
# 2, 2_backup_battery_quality_charge: 0.24212184873949566
# 3, 3_headphone_headphones_headset_gaming: 0.08963585434173668
# 4, 4_flipkart_flipcart_quality_product: 0.05637254901960782
# 5, 5_ear_ears_comfortable_listening: 0.023284313725490193
# 6, 6_headset_headphone_headphones_ear: 0.02696078431372549
# 7, 7_pros_pros1_bass_quality: -0.04201680672268907
# 8, 8_headphone_headphones_rs2000_headband: 0.03308823529411764
# 9, 9_headphones_headphone_headsets_prolonged: 0.030637254901960773
# 10, 10_quality_sound_stylish_qualitysound: 0.026960784313725485
# 11, 11_bluetooth_headphone_skype_audio: -0.1330532212885154
# 12, 12_base_sound_quality_aux: 0.08735994397759105
# 13, 13_bluetooth_headphone_bass_quality: 0.0196078431372549
# 14, 14_headsetflipkart_flipkart_headphone_bass55sound: 0.05409663865546219
# 15, 15_microphone_voice_headset_mic: 0.01715686274509804
# 16, 16_boatsound_headphonesgo_headphones_boat: 0.00980392156862745
# 17, 17_boat_battery_boats_charge: -0.05549719887955182
# 18, 18_headphone_bluetooththis_ears_bluetooth: 0.08245798319327731
# 19, 19_battery_charging_review_laptop: 0.012254901960784314
# 20, 20_cancellation_cancelation_neckband_quality: 0.014705882352941176
# 21, 21_headphones_headset_bluetooth_earphone: 0.04061624649859944
# 22, 22_headphonesreally_headphones_bass_price: 0.012254901960784312
# 23, 23_musicsbut_quality_audio_auxbut: 0.011029411764705883
# 24, 24_bass_bassgood_1010sound_battery: 0.014705882352941176
# 25, 25_headphones_headphoneslook_bass_headset: 0.011029411764705883
# 26, 26_headphone_headphones_headset_quality: 0.012254901960784314
# 27, 27_quality_sound_reliable_premium: 0.014705882352941176
# 28, 28_bass_basspadding_sound_playback: 0.011029411764705883
#
#   ---------------------
#
# boAt Wave Neo with 169 inch  2 being processed
# -1, -1_watch_sensor_tracking_battery: -0.000911369332421974
# 0, 0_watch_tracker_tracking_battery: -0.2761449077238551
# 1, 1_quality_valuable_product_reviews: 0.3668261562998405
# 2, 2_android_screen_monitoring_app: -0.1296422875370244
# 3, 3_dial_call_bluetooth_device: -0.2801321485532012
# 4, 4_backup_backupbut_backupcall_battery: 0.07518796992481203
# 5, 5_boat_wave_sensor_watch: 0.06015037593984962
#
#   ---------------------
#
# furlay Engineered Wood Study T being processed
# 0, 0_table_sturdy_assemble_monitor: 0.8131868131868134
# 1, 1_product_productyou_promising_durable: 0.23376623376623382
#
#   ---------------------
#
# limraz furniture Engineered Wo being processed
# -1, -1_legs_corners_monitors_leg: -0.33783783783783783
# 0, 0_quality_productworthable_productbuilt_product: 0.5675675675675677
# 1, 1_desk_table_desktop_laptop: 0.5135135135135135
# 2, 2_table_legs_leg_ergonomic: 0.08108108108108109
# 3, 3_table_quality_feedback_purchasing: -0.34749034749034746
#
#   ---------------------
#
# limraz furniture L 56 Engineer being processed
# -1, -1_chair_comfortable_chairits_laptop: 5.204170427930421e-18
# 0, 0_table_quality_laptop_design: -0.42105263157894723
# 1, 1_quality_flipkart_productthis_product: 0.2894736842105263
# 2, 2_legs_leg_table_shorter: -0.1789473684210526
# 3, 3_studying_study_studyto_useful: 0.12631578947368424
# 4, 4_table_studyworkdining_studysize_desk: 0.12631578947368421
# 5, 5_tables_table_foldable_portable: 0.15263157894736842
# 6, 6_table_laptopprice_pricing_priced: 0.09473684210526316
# 7, 7_sturdiness_quality_legs_reviews: 0.08421052631578947
# 8, 8_laptops_laptop_table_tabletop: 0.07368421052631578
# 9, 9_stand_tilted_surface_unstable: -0.2631578947368421
#
#   ---------------------
#
# realme 4k Smart Google TV Stic being processed
# -1, -1_chromecast_streaming_surround_hd: -0.05405405405405406
# 0, 0_tv_android_firestick_hdr: 0.4348894348894348
# 1, 1_remote_service_stopped_connecting: -0.945945945945946
#
#   ---------------------
#
# realme Mobile Game Finger Slee being processed
# -1, -1_quality_realme_branding_logo: -0.09486166007905139
# 0, 0_reviews_buy_use_product: -1.2252964426877473
# 1, 1_quality_smooth_smoothness_smoothyou: -0.055335968379446654
# 2, 2_sleeve_sleeves_finger_touchpad: 0.3873517786561265
# 3, 3_sweat_sweaty_comfortable_finger: 0.5217391304347826
#
#   ---------------------
#
# realme Pad X 6 GB RAM 128 GB R being processed
# -1, -1_performance_backup_backupdisplay_battery: -0.002857142857142836
# 0, 0_tablet_ipad_performance_android: 0.40428571428571447
# 1, 1_audio_quality_headphone_sound: 0.09142857142857143
# 2, 2_tablet_5g_realme_padxwifi: 0.08714285714285717
# 3, 3_otg_3g4gas_airtel_sim: -0.05714285714285713
# 4, 4_tab_taboverall_3days_performance: 0.15
# 5, 5_flipkart_purchase_quality_productsound: -0.01285714285714285
# 6, 6_awesomeaudio_tab_audio_tabonly: 0.06999999999999999
# 7, 7_storage_price_rate_worth: -0.11285714285714285
#
#   ---------------------
#
# realme Smart Tv Stick Media St being processed
# 0, 0_hdmi_1080p_laggy_tv: 1.1085526315789473
# 1, 1_remote_devicepurchase_tv_device: -0.8848684210526315
#
#   ---------------------
#
# realme TechLife 75 kg 5 Star R being processed
# -1, -1_plastic_75kg_material_durable: -0.2167487684729064
# 0, 0_machine_motor_realme_washing: -0.05172413793103445
# 1, 1_washing_wash_cloth_machine: 0.4088669950738917
# 2, 2_very_review_product_performence: 0.6896551724137931
# 3, 3_dryer_dry_lint_drier: -0.25
#
#   ---------------------
#
# sanyasi ayurveda Sanyasi Sehat being processed
# -1, -1_tablets_eat_sahat_gain: 0.04081632653061224
# 0, 0_diet_appetite_gain_ayurvedic: -0.09843937575030012
# 1, 1_productweight_diet_gain_weightyou: 0.6170468187274911
# 2, 2_effect_product_productdont_flipkart: -0.148859543817527
# 3, 3_ayurveda_ayurvedic_aayurvedic_ayurved: 0.39855942376950776
#
#   ---------------------
#
# thos 5 Layer Simple BookshelfM being processed
# 0, 0_assemble_quality_product_parts: -0.7866666666666665
# 1, 1_sturdy_shelves_rods_materials: 0.14000000000000004
# 2, 2_sturdy_stand_weight_quality: 0.2
